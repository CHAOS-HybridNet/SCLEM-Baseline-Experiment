# %% [markdown]
# # Example with a regressed target metric due to Population Bias
#
# Here is an example of a pair of  Control and Treatment datasets where the regression in target metric is due to population bias. We will see that after the datasets are normalized, there is no more statistical differences between two datasets.

# %%
import os
import pandas as pd
import hashlib
import json
from mct.BiasTester import BiasTester
from mct.MetricComparer import MetricComparer
# Out:
# /home/sunyongqian/miniconda3/envs/Lumos/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
id='25969'
# 创建结果保存的文件夹
results_dir = f'results_{id}'
os.makedirs(results_dir, exist_ok=True)

# %%
# 生成字符串的MD5码
def generate_md5(input_string):
    md5_object = hashlib.md5()
    md5_object.update(input_string.encode('utf-8'))
    return md5_object.hexdigest()

# %%
# 定义文件路径
kpi_file = f'/home/zhengtinghua/shenchao/baseline/new_dataset/train/{id}/train_kpi.csv'
log_file = f'/home/zhengtinghua/shenchao/baseline/new_dataset/train/{id}/train_log.csv'
train_output_file = f'/home/zhengtinghua/shenchao/baseline/new_dataset/train/{id}/train_combined.csv'

# 读取两个 CSV 文件
kpi_df = pd.read_csv(kpi_file)
log_df = pd.read_csv(log_file)

# 确保两个 DataFrame 的行数相同
if len(kpi_df) != len(log_df):
    raise ValueError("两个 CSV 文件的行数不一致。请检查数据。")

# 合并 DataFrame
combined_df = pd.concat([log_df,kpi_df], axis=1)

# 获取原始列名并转换为MD5码
md5_column_names = {col: generate_md5(col) for col in combined_df.columns}

# 输出属性名的MD5码
for original, md5_name in md5_column_names.items():
    print(f"Original column name: {original}, MD5 hash: {md5_name}")

# # 获取当前所有列名
# original_columns = combined_df.columns
# #修改输出后的列名
# new_columns = [f'invariant_columns_{i}' for i in range(len(original_columns))]
# combined_df.columns = new_columns

# 修改最后一列的列名
last_column_name = combined_df.columns[-1]
combined_df.rename(columns={last_column_name: 'target_metric'}, inplace=True)

# 保存合并后的数据到新文件
combined_df.to_csv(train_output_file, index=False)

# 目标目录
target_dir = f'/home/sunyongqian/liuheng/shenchao/Lumos/results_{id}'
# 确保目标目录存在，如果不存在则创建
os.makedirs(target_dir, exist_ok=True)
output_file = os.path.join(target_dir, 'train_combined.csv')
combined_df.to_csv(output_file, index=False)

print(f"数据已成功合并并保存到 {output_file}")
# Out:
# Original column name: isEqualDirectSuperior failed, err=fanweiEmployee not exist in yid, MD5 hash: 676d60696ca737db0634b52c6d7625aa
# Original column name: [isEqualDirectSuperior] fanwei Employee not exist in yid, MD5 hash: b0c52740b2c50bfce18ca4b4abe54589
# Original column name: the employee does not exist, MD5 hash: 8ae34a213e21ba77a38bd7cb4c9ab59c
# Original column name: not find dictionary type=<:NUM:>, MD5 hash: 49a31c561aad9ddcfc906e27c33d8de5
# Original column name: AuthSessionVali<:updateFanweiEmployee failed:>, MD5 hash: 6689748c163274d0b5ff0da639c826c0
# Original column name: [getOtpKey] <:*:> failed:>, MD5 hash: 3ef3bde3ec13d1e570e0609ce3ea2f39
# Original column name: [securitySessionCheck] GetSecuritySessionFromReq failed, err=securecookie: expired timestamp [trace.id=<:SEQ:> <:transactionID:> <:spanID:>, MD5 hash: a52809c13042e72dfad83cec67c9eb77
# Original column name: [securitySessionCheck] CreatAndSaveSessio<:updateFanweiEmployee failed:>, MD5 hash: 1a2716f0775e9300c7518464840cf343
# Original column name: [GetWeChatUserInfo] GetWeChatUserInf<:updateFanweiEmployee failed:>, MD5 hash: 8499e67a0244c115d426a91953519c53
# Original column name: can't find addEmp from updateEmp and empMapTo, MD5 hash: 13798bb85b5c1ce6e7a783b4fce44aa5
# Original column name: [SimplePost] failed, <:ERRORPost:>, MD5 hash: 12d5cd61a42914cacec183ade297e1ff
# Original column name: [UpdateEmployee] <:SimplePos<:updateFanweiEmployee failed:>, MD5 hash: 35ba7cab09d5fc65e748045b231a4ffc
# Original column name: [updateFanweiEmployee] failed, <:updateEmployeeData:>, MD5 hash: 0bb4a64c2f8bc65062a8fc8abec892e6
# Original column name: no employee, MD5 hash: dd2fa201931efc8167208477934b8341
# Original column name: timestamp, MD5 hash: d7e6d55ba379a13d08c25d15faf2a23b
# Original column name: unknown, MD5 hash: ad921d60486366258809553a3db49a4a
# Original column name: 1-avg(irate(node_cpu_seconds_total{hostname=~"bj1-rd-yos-prod-01", mode=~"idle"}[1m])) by (mode, hostname), MD5 hash: 79d22d965f691995213f39a244c42642
# Original column name: node_load1{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: aa4a9a884d912744e3b66ffa4af133da
# Original column name: node_load5{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 7217d098f5e181358a205b1e180a0d3b
# Original column name: node_load15{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 85a748724dab61284a4f8fbf5d1d517d
# Original column name: (1-(node_memory_MemAvailable_bytes{hostname=~"bj1-rd-yos-prod-01"}/node_memory_MemTotal_bytes{hostname=~"bj1-rd-yos-prod-01"}))*100, MD5 hash: bf4221c2d695400e105fe1c2c77f4bab
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/"} / node_filesystem_size_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/"}), MD5 hash: e2e220cba8dbc89a9a7c445a3e5a4c03
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/data"} / node_filesystem_size_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/data"}), MD5 hash: f6ccb0574e1aa6dfa7acfe855bf3f0ed
# Original column name: irate(node_disk_reads_completed_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: ad7eb84adef7568fefcba3de998fc181
# Original column name: irate(node_disk_writes_completed_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 715d4137c8a1353a947b1a209ec15ebf
# Original column name: irate(node_disk_read_time_seconds_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: c8ef987db562f16d0ceea527257af66e
# Original column name: irate(node_disk_write_time_seconds_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 7a03ff2f18f88217019889b25df172c7
# Original column name: irate(node_disk_read_bytes_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 05e46e802dfe8ff237d8be3cc04357d0
# Original column name: irate(node_disk_written_bytes_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: e50a2f224ce325b5bc686e2cd500511c
# Original column name: node_netstat_Tcp_CurrEstab{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 1813611bb23d23a943980cdb9608722b
# Original column name: node_sockstat_TCP_tw{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 5669240684962db428f2f9db643f37b6
# Original column name: irate(node_netstat_Tcp_ActiveOpens{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 17da86476631e19f56aae1ab573d1ecd
# Original column name: irate(node_netstat_Tcp_PassiveOpens{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 28da0fb03f15abda273f4d84c54b2622
# Original column name: node_sockstat_TCP_alloc{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: ad28d721042558deceedcc158daa653a
# Original column name: node_sockstat_TCP_inuse{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: ffc8e6786dd99da5b5ef08f7047d1908
# Original column name: probe_duration_seconds{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 8ba619860d5d299eb9ebeb6ed5a1b1ab
# Original column name: irate(node_network_receive_bytes_total{hostname=~"bj1-rd-yos-prod-01",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 6dd142bb2bc432e45c4148504520a43e
# Original column name: irate(node_network_transmit_bytes_total{hostname=~"bj1-rd-yos-prod-01",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 7cdc0ca33bb506c3863f26e4cd7d8141
# Original column name: 1-avg(irate(node_cpu_seconds_total{hostname=~"bj3-rd-yos-prod-03", mode=~"idle"}[1m])) by (mode, hostname), MD5 hash: 12ce2f8a387b46f2983d293395cc30aa
# Original column name: node_load1{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: bdde7e67f9a95deec89f47f81a4c4d28
# Original column name: node_load5{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: d70cc408179b07370cfea893eb27c2e6
# Original column name: node_load15{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 41196efa2e9e635b4e1614b35023c273
# Original column name: (1-(node_memory_MemAvailable_bytes{hostname=~"bj3-rd-yos-prod-03"}/node_memory_MemTotal_bytes{hostname=~"bj3-rd-yos-prod-03"}))*100, MD5 hash: 51aafe0d283539e6f544458b3a8101d8
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/"}), MD5 hash: 85488cb00387ef5431a0787442ad5fd1
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/data"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/data"}), MD5 hash: 6d5a1e1ee6f47403689e4bdee8b5cbbd
# Original column name: irate(node_disk_reads_completed_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 465d449bf52b6475db5c70956c4e7baf
# Original column name: irate(node_disk_writes_completed_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 03037d8e63e98e3af5fec33c23c14558
# Original column name: irate(node_disk_read_time_seconds_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 49cfb420c8caabbced85517d140e86bc
# Original column name: irate(node_disk_write_time_seconds_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: be6d2929bd42034d9f5d2ca0f2f9a241
# Original column name: irate(node_disk_read_bytes_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: aea60dcd98b92fdc7d29f10aeda7d276
# Original column name: irate(node_disk_written_bytes_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 58b4f6c5a31e43583678d763bab9106b
# Original column name: node_netstat_Tcp_CurrEstab{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 6a163021c878bd75eff0a9b2658d0e19
# Original column name: node_sockstat_TCP_tw{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 768f3284d8f86e70aa2bc6b907b0b9b5
# Original column name: irate(node_netstat_Tcp_ActiveOpens{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 3c04d10fe6b64f3ad338b9a937ebc88f
# Original column name: irate(node_netstat_Tcp_PassiveOpens{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: e94c1670381ed1d2997c61dbe961d7c8
# Original column name: node_sockstat_TCP_alloc{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 03d7ae838a189af0b39068db24f7cce8
# Original column name: node_sockstat_TCP_inuse{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 86bb6ec780065a02ee1d8b3149304ba1
# Original column name: probe_duration_seconds{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 7d149192ff62ce65437ce8f02b093c90
# Original column name: irate(node_network_receive_bytes_total{hostname=~"bj3-rd-yos-prod-03",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: d5d765be3cd14f128442dfe5abc3df53
# Original column name: irate(node_network_transmit_bytes_total{hostname=~"bj3-rd-yos-prod-03",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 23396d0dd4ea97aa7af94c024e292303
# Original column name: 1-avg(irate(node_cpu_seconds_total{hostname=~"bj3-rd-yos-prod-02", mode=~"idle"}[1m])) by (mode, hostname), MD5 hash: d9577e782969b178e1561702d6587b0f
# Original column name: node_load1{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 286b846a3bb1b99dc02bc35122ad5793
# Original column name: node_load5{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 43909a8782fa8a4888c62b67d7768e10
# Original column name: node_load15{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 195f1ef5bb116a44f59cc56fa3805ece
# Original column name: (1-(node_memory_MemAvailable_bytes{hostname=~"bj3-rd-yos-prod-02"}/node_memory_MemTotal_bytes{hostname=~"bj3-rd-yos-prod-02"}))*100, MD5 hash: 073655d53852254cc1f77f9eed2fdb35
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/"}), MD5 hash: 26f40f18df617d03d04c7c7ab1a22654
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/data"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/data"}), MD5 hash: f48f2213be23318724c22d30aa3ec7b1
# Original column name: irate(node_disk_reads_completed_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: b016ca5ab39fc5601c3ee843cfee05a0
# Original column name: irate(node_disk_writes_completed_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 4e15b1051b3136355a241e5572b5bd9d
# Original column name: irate(node_disk_read_time_seconds_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 44d1fa3c4d88605df22961f2df3225c3
# Original column name: irate(node_disk_write_time_seconds_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 3584d6fc0304ceb250c5c5ec4fe69264
# Original column name: irate(node_disk_read_bytes_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: dd08fb9d8a503d57f49c814860f8923e
# Original column name: irate(node_disk_written_bytes_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: e0b5003c73c7d2b83459f06fae09a595
# Original column name: node_netstat_Tcp_CurrEstab{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: fbffbee51c145da6e65ff769433d6be9
# Original column name: node_sockstat_TCP_tw{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 54c093b01c7b0c2ebd6d6aa21ada9335
# Original column name: irate(node_netstat_Tcp_ActiveOpens{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 92ac5cac29afec4badbbc3f7bbd68855
# Original column name: irate(node_netstat_Tcp_PassiveOpens{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: f93d8b95ed6d8c181e69041e523ae5e7
# Original column name: node_sockstat_TCP_alloc{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: a97dd74d4b74f9fd4b6ba892fb66c57a
# Original column name: node_sockstat_TCP_inuse{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: c2bd34b4ed1126c0e52de18b4b4a2d6c
# Original column name: probe_duration_seconds{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: a557d68555308de53f9b2a1fa5865e1d
# Original column name: irate(node_network_receive_bytes_total{hostname=~"bj3-rd-yos-prod-02",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: d069794b5eb9c389fad4ff7366cbdfcf
# Original column name: irate(node_network_transmit_bytes_total{hostname=~"bj3-rd-yos-prod-02",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 6418faf2f05fc1652a9a80ed1dc23a1a
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources", grpc_code="Unknown"}[5m])), MD5 hash: c74e69fa62d039053624cdd93fca0609
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources", grpc_code="OK"}[5m])), MD5 hash: e728b8f15625cc0f2b65d6213315aa64
# Original column name: sum(rate(std_requests_total{job="be/yid", code="200",method=~"GET|POST",url=~"/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[5m])), MD5 hash: b608bcd1c48bdafdbca71a1e554fda15
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid", grpc_code="Unknown",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[5m])), MD5 hash: 7707f5028f4594ae685a0ae3e384a7fd
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid", grpc_code="OK",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[5m])), MD5 hash: 25814db645b9840b611ea7f69e678f8d
# Original column name: sum(rate(std_requests_total{job="be/yid", code="200",method="GET",url=~"/api/v1/employee/:empID|/api/v1/employees|/api/v1/dept|/api/v1/depts|/api/v1/team/:teamID|/api/v1/teams|/api/v1/supervisors/:empIDs|/api/v1/dept-tree|/api/v1/emplist"}[5m])), MD5 hash: 7f5223653c540a241a5113c45ee7a4ed
# Original column name: 1- ((sum(increase(std_requests_total{job="be/yid",code="200",environment="prod", bizcode="6000"}[5m]) or increase(std_requests_total{job="$service",environment="be/yid", code=~"5.."}[5m]))  or  vector(0)) /  sum(increase(std_requests_total{job="be/yid",environment="prod"}[5m]))), MD5 hash: a8b316b1ec122163ef3a36a8eb4be4a0
# Original column name: 1-sum(increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",environment="prod",grpc_code=~"Unknown|OK"}[5m]) or increase(std_grpc_server_handled_total{job="be/yid",environment="prod",grpc_code!~"Unknown|OK"}[5m]))/sum(increase(std_grpc_server_handled_total{job="be/yid",environment="prod"}[5m])) or vector(1), MD5 hash: f565ad4dcd8c71ae492c926eb2cd68e8
# Original column name: sum(rate(std_requests_total{job="be/yid",code=~"2..",environment="prod"}[5m])), MD5 hash: 3c849f3e30133c842c13c7d65dd48e30
# Original column name: sum(rate(std_requests_total{job="be/yid",code=~"3..",environment="prod"}[5m])), MD5 hash: 1698f3366a82e7435c6cdc184efcc092
# Original column name: sum(rate(std_requests_total{job="be/yid",code=~"4..",environment="prod"}[5m])), MD5 hash: 78423c035b5808cb2d83040d00ced068
# Original column name: (1-sum(increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_code=~"Unknown|OK",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources"}[2m]) or increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources"}[2m]) or vector(0))/sum(increase(std_grpc_server_handled_total{job="be/yid",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources"}[2m])))*100, MD5 hash: 99347dd2b81f4ba08f966ffa59d12ed8
# Original column name: (1-sum(increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_code=~"Unknown|OK",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[2m]) or increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[2m]) or vector(0))/sum(increase(std_grpc_server_handled_total{job="be/yid",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[2m])))*100, MD5 hash: 618f72611b4ca585740176d000919f73
# Original column name: (1- (sum(increase(std_requests_total{job="be/yid",code="200",bizcode="6000",method=~"GET|POST",url=~"/sso/oauth2/auth|/sso/oauth2/token|/sso/oauth2/revoke|sso/userinfo|/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[2m]) or increase(std_requests_total{job="be/yid",code=~"5..",method=~"GET|POST",url=~"/sso/oauth2/auth|/sso/oauth2/token|/sso/oauth2/revoke|sso/userinfo|/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[2m])) or vector(0)) / sum(increase(std_requests_total{job="be/yid",method=~"GET|POST",url=~"/sso/oauth2/auth|/sso/oauth2/token|/sso/oauth2/revoke|sso/userinfo|/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[2m])))*100, MD5 hash: 5280ceb9f6db7db00f7cd3ac167e2480
# Original column name: yid_login_rate{exported_job="yid_login",instance="172.16.17.3:9092",job="push-gateway"}, MD5 hash: 7d14029bfe702b3710527442adf6e55a
# 数据已成功合并并保存到 /home/sunyongqian/liuheng/shenchao/Lumos/results_25969/train_combined.csv

# %%
# 定义文件路径
kpi_file = f'/home/zhengtinghua/shenchao/baseline/new_dataset/test/{id}/test_kpi.csv'
log_file = f'/home/zhengtinghua/shenchao/baseline/new_dataset/test/{id}/test_log.csv'
test_output_file = f'/home/zhengtinghua/shenchao/baseline/new_dataset/test/{id}/test_combined.csv'

# 读取两个 CSV 文件
kpi_df = pd.read_csv(kpi_file)
log_df = pd.read_csv(log_file)

# 确保两个 DataFrame 的行数相同
if len(kpi_df) != len(log_df):
    raise ValueError("两个 CSV 文件的行数不一致。请检查数据。")

# 合并 DataFrame
combined_df = pd.concat([log_df,kpi_df], axis=1)

# 获取原始列名并转换为MD5码
md5_column_names = {col: generate_md5(col) for col in combined_df.columns}

# 输出属性名的MD5码
for original, md5_name in md5_column_names.items():
    print(f"Original column name: {original}, MD5 hash: {md5_name}")

# 修改最后一列的列名
last_column_name = combined_df.columns[-1]
combined_df.rename(columns={last_column_name: 'target_metric'}, inplace=True)

# 保存合并后的数据到新文件
combined_df.to_csv(test_output_file, index=False)

# 目标目录
target_dir = f'/home/sunyongqian/liuheng/shenchao/Lumos/results_{id}'
# 确保目标目录存在，如果不存在则创建
os.makedirs(target_dir, exist_ok=True)
output_file = os.path.join(target_dir, 'test_combined.csv')
combined_df.to_csv(output_file, index=False)
print(f"数据已成功合并并保存到 {output_file}")
# Out:
# Original column name: isEqualDirectSuperior failed, err=fanweiEmployee not exist in yid, MD5 hash: 676d60696ca737db0634b52c6d7625aa
# Original column name: [isEqualDirectSuperior] fanwei Employee not exist in yid, MD5 hash: b0c52740b2c50bfce18ca4b4abe54589
# Original column name: the employee does not exist, MD5 hash: 8ae34a213e21ba77a38bd7cb4c9ab59c
# Original column name: not find dictionary type=<:NUM:>, MD5 hash: 49a31c561aad9ddcfc906e27c33d8de5
# Original column name: AuthSessionVali<:updateFanweiEmployee failed:>, MD5 hash: 6689748c163274d0b5ff0da639c826c0
# Original column name: [getOtpKey] <:*:> failed:>, MD5 hash: 3ef3bde3ec13d1e570e0609ce3ea2f39
# Original column name: [securitySessionCheck] GetSecuritySessionFromReq failed, err=securecookie: expired timestamp [trace.id=<:SEQ:> <:transactionID:> <:spanID:>, MD5 hash: a52809c13042e72dfad83cec67c9eb77
# Original column name: [securitySessionCheck] CreatAndSaveSessio<:updateFanweiEmployee failed:>, MD5 hash: 1a2716f0775e9300c7518464840cf343
# Original column name: [GetWeChatUserInfo] GetWeChatUserInf<:updateFanweiEmployee failed:>, MD5 hash: 8499e67a0244c115d426a91953519c53
# Original column name: can't find addEmp from updateEmp and empMapTo, MD5 hash: 13798bb85b5c1ce6e7a783b4fce44aa5
# Original column name: [SimplePost] failed, <:ERRORPost:>, MD5 hash: 12d5cd61a42914cacec183ade297e1ff
# Original column name: [UpdateEmployee] <:SimplePos<:updateFanweiEmployee failed:>, MD5 hash: 35ba7cab09d5fc65e748045b231a4ffc
# Original column name: [updateFanweiEmployee] failed, <:updateEmployeeData:>, MD5 hash: 0bb4a64c2f8bc65062a8fc8abec892e6
# Original column name: no employee, MD5 hash: dd2fa201931efc8167208477934b8341
# Original column name: timestamp, MD5 hash: d7e6d55ba379a13d08c25d15faf2a23b
# Original column name: unknown, MD5 hash: ad921d60486366258809553a3db49a4a
# Original column name: 1-avg(irate(node_cpu_seconds_total{hostname=~"bj1-rd-yos-prod-01", mode=~"idle"}[1m])) by (mode, hostname), MD5 hash: 79d22d965f691995213f39a244c42642
# Original column name: node_load1{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: aa4a9a884d912744e3b66ffa4af133da
# Original column name: node_load5{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 7217d098f5e181358a205b1e180a0d3b
# Original column name: node_load15{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 85a748724dab61284a4f8fbf5d1d517d
# Original column name: (1-(node_memory_MemAvailable_bytes{hostname=~"bj1-rd-yos-prod-01"}/node_memory_MemTotal_bytes{hostname=~"bj1-rd-yos-prod-01"}))*100, MD5 hash: bf4221c2d695400e105fe1c2c77f4bab
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/"} / node_filesystem_size_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/"}), MD5 hash: e2e220cba8dbc89a9a7c445a3e5a4c03
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/data"} / node_filesystem_size_bytes{hostname=~"bj1-rd-yos-prod-01",fstype=~"ext4|xfs",mountpoint="/data"}), MD5 hash: f6ccb0574e1aa6dfa7acfe855bf3f0ed
# Original column name: irate(node_disk_reads_completed_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: ad7eb84adef7568fefcba3de998fc181
# Original column name: irate(node_disk_writes_completed_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 715d4137c8a1353a947b1a209ec15ebf
# Original column name: irate(node_disk_read_time_seconds_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: c8ef987db562f16d0ceea527257af66e
# Original column name: irate(node_disk_write_time_seconds_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 7a03ff2f18f88217019889b25df172c7
# Original column name: irate(node_disk_read_bytes_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 05e46e802dfe8ff237d8be3cc04357d0
# Original column name: irate(node_disk_written_bytes_total{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: e50a2f224ce325b5bc686e2cd500511c
# Original column name: node_netstat_Tcp_CurrEstab{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 1813611bb23d23a943980cdb9608722b
# Original column name: node_sockstat_TCP_tw{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 5669240684962db428f2f9db643f37b6
# Original column name: irate(node_netstat_Tcp_ActiveOpens{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 17da86476631e19f56aae1ab573d1ecd
# Original column name: irate(node_netstat_Tcp_PassiveOpens{hostname=~"bj1-rd-yos-prod-01"}[1m]), MD5 hash: 28da0fb03f15abda273f4d84c54b2622
# Original column name: node_sockstat_TCP_alloc{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: ad28d721042558deceedcc158daa653a
# Original column name: node_sockstat_TCP_inuse{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: ffc8e6786dd99da5b5ef08f7047d1908
# Original column name: probe_duration_seconds{hostname=~"bj1-rd-yos-prod-01"}, MD5 hash: 8ba619860d5d299eb9ebeb6ed5a1b1ab
# Original column name: irate(node_network_receive_bytes_total{hostname=~"bj1-rd-yos-prod-01",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 6dd142bb2bc432e45c4148504520a43e
# Original column name: irate(node_network_transmit_bytes_total{hostname=~"bj1-rd-yos-prod-01",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 7cdc0ca33bb506c3863f26e4cd7d8141
# Original column name: 1-avg(irate(node_cpu_seconds_total{hostname=~"bj3-rd-yos-prod-03", mode=~"idle"}[1m])) by (mode, hostname), MD5 hash: 12ce2f8a387b46f2983d293395cc30aa
# Original column name: node_load1{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: bdde7e67f9a95deec89f47f81a4c4d28
# Original column name: node_load5{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: d70cc408179b07370cfea893eb27c2e6
# Original column name: node_load15{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 41196efa2e9e635b4e1614b35023c273
# Original column name: (1-(node_memory_MemAvailable_bytes{hostname=~"bj3-rd-yos-prod-03"}/node_memory_MemTotal_bytes{hostname=~"bj3-rd-yos-prod-03"}))*100, MD5 hash: 51aafe0d283539e6f544458b3a8101d8
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/"}), MD5 hash: 85488cb00387ef5431a0787442ad5fd1
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/data"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-03",fstype=~"ext4|xfs",mountpoint="/data"}), MD5 hash: 6d5a1e1ee6f47403689e4bdee8b5cbbd
# Original column name: irate(node_disk_reads_completed_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 465d449bf52b6475db5c70956c4e7baf
# Original column name: irate(node_disk_writes_completed_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 03037d8e63e98e3af5fec33c23c14558
# Original column name: irate(node_disk_read_time_seconds_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 49cfb420c8caabbced85517d140e86bc
# Original column name: irate(node_disk_write_time_seconds_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: be6d2929bd42034d9f5d2ca0f2f9a241
# Original column name: irate(node_disk_read_bytes_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: aea60dcd98b92fdc7d29f10aeda7d276
# Original column name: irate(node_disk_written_bytes_total{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 58b4f6c5a31e43583678d763bab9106b
# Original column name: node_netstat_Tcp_CurrEstab{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 6a163021c878bd75eff0a9b2658d0e19
# Original column name: node_sockstat_TCP_tw{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 768f3284d8f86e70aa2bc6b907b0b9b5
# Original column name: irate(node_netstat_Tcp_ActiveOpens{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: 3c04d10fe6b64f3ad338b9a937ebc88f
# Original column name: irate(node_netstat_Tcp_PassiveOpens{hostname=~"bj3-rd-yos-prod-03"}[1m]), MD5 hash: e94c1670381ed1d2997c61dbe961d7c8
# Original column name: node_sockstat_TCP_alloc{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 03d7ae838a189af0b39068db24f7cce8
# Original column name: node_sockstat_TCP_inuse{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 86bb6ec780065a02ee1d8b3149304ba1
# Original column name: probe_duration_seconds{hostname=~"bj3-rd-yos-prod-03"}, MD5 hash: 7d149192ff62ce65437ce8f02b093c90
# Original column name: irate(node_network_receive_bytes_total{hostname=~"bj3-rd-yos-prod-03",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: d5d765be3cd14f128442dfe5abc3df53
# Original column name: irate(node_network_transmit_bytes_total{hostname=~"bj3-rd-yos-prod-03",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 23396d0dd4ea97aa7af94c024e292303
# Original column name: 1-avg(irate(node_cpu_seconds_total{hostname=~"bj3-rd-yos-prod-02", mode=~"idle"}[1m])) by (mode, hostname), MD5 hash: d9577e782969b178e1561702d6587b0f
# Original column name: node_load1{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 286b846a3bb1b99dc02bc35122ad5793
# Original column name: node_load5{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 43909a8782fa8a4888c62b67d7768e10
# Original column name: node_load15{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 195f1ef5bb116a44f59cc56fa3805ece
# Original column name: (1-(node_memory_MemAvailable_bytes{hostname=~"bj3-rd-yos-prod-02"}/node_memory_MemTotal_bytes{hostname=~"bj3-rd-yos-prod-02"}))*100, MD5 hash: 073655d53852254cc1f77f9eed2fdb35
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/"}), MD5 hash: 26f40f18df617d03d04c7c7ab1a22654
# Original column name: 1-(node_filesystem_free_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/data"} / node_filesystem_size_bytes{hostname=~"bj3-rd-yos-prod-02",fstype=~"ext4|xfs",mountpoint="/data"}), MD5 hash: f48f2213be23318724c22d30aa3ec7b1
# Original column name: irate(node_disk_reads_completed_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: b016ca5ab39fc5601c3ee843cfee05a0
# Original column name: irate(node_disk_writes_completed_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 4e15b1051b3136355a241e5572b5bd9d
# Original column name: irate(node_disk_read_time_seconds_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 44d1fa3c4d88605df22961f2df3225c3
# Original column name: irate(node_disk_write_time_seconds_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 3584d6fc0304ceb250c5c5ec4fe69264
# Original column name: irate(node_disk_read_bytes_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: dd08fb9d8a503d57f49c814860f8923e
# Original column name: irate(node_disk_written_bytes_total{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: e0b5003c73c7d2b83459f06fae09a595
# Original column name: node_netstat_Tcp_CurrEstab{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: fbffbee51c145da6e65ff769433d6be9
# Original column name: node_sockstat_TCP_tw{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: 54c093b01c7b0c2ebd6d6aa21ada9335
# Original column name: irate(node_netstat_Tcp_ActiveOpens{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: 92ac5cac29afec4badbbc3f7bbd68855
# Original column name: irate(node_netstat_Tcp_PassiveOpens{hostname=~"bj3-rd-yos-prod-02"}[1m]), MD5 hash: f93d8b95ed6d8c181e69041e523ae5e7
# Original column name: node_sockstat_TCP_alloc{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: a97dd74d4b74f9fd4b6ba892fb66c57a
# Original column name: node_sockstat_TCP_inuse{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: c2bd34b4ed1126c0e52de18b4b4a2d6c
# Original column name: probe_duration_seconds{hostname=~"bj3-rd-yos-prod-02"}, MD5 hash: a557d68555308de53f9b2a1fa5865e1d
# Original column name: irate(node_network_receive_bytes_total{hostname=~"bj3-rd-yos-prod-02",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: d069794b5eb9c389fad4ff7366cbdfcf
# Original column name: irate(node_network_transmit_bytes_total{hostname=~"bj3-rd-yos-prod-02",device!~"tap.*|veth.*|br.*|docker.*|virbr*|lo*"}[5m])*8, MD5 hash: 6418faf2f05fc1652a9a80ed1dc23a1a
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources", grpc_code="Unknown"}[5m])), MD5 hash: c74e69fa62d039053624cdd93fca0609
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources", grpc_code="OK"}[5m])), MD5 hash: e728b8f15625cc0f2b65d6213315aa64
# Original column name: sum(rate(std_requests_total{job="be/yid", code="200",method=~"GET|POST",url=~"/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[5m])), MD5 hash: b608bcd1c48bdafdbca71a1e554fda15
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid", grpc_code="Unknown",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[5m])), MD5 hash: 7707f5028f4594ae685a0ae3e384a7fd
# Original column name: sum(rate(std_grpc_server_handled_total{job="be/yid", grpc_code="OK",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[5m])), MD5 hash: 25814db645b9840b611ea7f69e678f8d
# Original column name: sum(rate(std_requests_total{job="be/yid", code="200",method="GET",url=~"/api/v1/employee/:empID|/api/v1/employees|/api/v1/dept|/api/v1/depts|/api/v1/team/:teamID|/api/v1/teams|/api/v1/supervisors/:empIDs|/api/v1/dept-tree|/api/v1/emplist"}[5m])), MD5 hash: 7f5223653c540a241a5113c45ee7a4ed
# Original column name: 1- ((sum(increase(std_requests_total{job="be/yid",code="200",environment="prod", bizcode="6000"}[5m]) or increase(std_requests_total{job="$service",environment="be/yid", code=~"5.."}[5m]))  or  vector(0)) /  sum(increase(std_requests_total{job="be/yid",environment="prod"}[5m]))), MD5 hash: a8b316b1ec122163ef3a36a8eb4be4a0
# Original column name: 1-sum(increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",environment="prod",grpc_code=~"Unknown|OK"}[5m]) or increase(std_grpc_server_handled_total{job="be/yid",environment="prod",grpc_code!~"Unknown|OK"}[5m]))/sum(increase(std_grpc_server_handled_total{job="be/yid",environment="prod"}[5m])) or vector(1), MD5 hash: f565ad4dcd8c71ae492c926eb2cd68e8
# Original column name: sum(rate(std_requests_total{job="be/yid",code=~"2..",environment="prod"}[5m])), MD5 hash: 3c849f3e30133c842c13c7d65dd48e30
# Original column name: sum(rate(std_requests_total{job="be/yid",code=~"3..",environment="prod"}[5m])), MD5 hash: 1698f3366a82e7435c6cdc184efcc092
# Original column name: sum(rate(std_requests_total{job="be/yid",code=~"4..",environment="prod"}[5m])), MD5 hash: 78423c035b5808cb2d83040d00ced068
# Original column name: (1-sum(increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_code=~"Unknown|OK",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources"}[2m]) or increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources"}[2m]) or vector(0))/sum(increase(std_grpc_server_handled_total{job="be/yid",grpc_method=~"ListFieldValues|ListPermResource|CheckUserOperatePage|ListAuthZResources"}[2m])))*100, MD5 hash: 99347dd2b81f4ba08f966ffa59d12ed8
# Original column name: (1-sum(increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_code=~"Unknown|OK",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[2m]) or increase(std_grpc_server_handled_total{job="be/yid",biz_code="6000",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[2m]) or vector(0))/sum(increase(std_grpc_server_handled_total{job="be/yid",grpc_method=~"GetEmployee|ListEmployee|GetDepartment|ListDepartment|GetTeam|ListTeam|ListSupervisor|IsDeptLeader|GetDepartTree|GetEmployeeDepartTree|ListUserNameByEmpID|ListAuthZTeamsByUserName|ListWeChatDeptIDByDeptID|ListJiesuanBusinessDeptMember|ListAllInternalEmployees|IsEmployeeBelongToDept|ListApproveAuthEmp|ListApproveAuthDept|ListApproveBackupEmp"}[2m])))*100, MD5 hash: 618f72611b4ca585740176d000919f73
# Original column name: (1- (sum(increase(std_requests_total{job="be/yid",code="200",bizcode="6000",method=~"GET|POST",url=~"/sso/oauth2/auth|/sso/oauth2/token|/sso/oauth2/revoke|sso/userinfo|/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[2m]) or increase(std_requests_total{job="be/yid",code=~"5..",method=~"GET|POST",url=~"/sso/oauth2/auth|/sso/oauth2/token|/sso/oauth2/revoke|sso/userinfo|/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[2m])) or vector(0)) / sum(increase(std_requests_total{job="be/yid",method=~"GET|POST",url=~"/sso/oauth2/auth|/sso/oauth2/token|/sso/oauth2/revoke|sso/userinfo|/api/v2/user/publickey|/api/v2/user/login|/api/v2/user/verify/totp|/api/v2/user/password/change|/api/v2/email/password|/api/v2/password/auth|/api/v2/password/reset"}[2m])))*100, MD5 hash: 5280ceb9f6db7db00f7cd3ac167e2480
# Original column name: yid_login_rate{exported_job="yid_login",instance="172.16.17.3:9092",job="push-gateway"}, MD5 hash: 7d14029bfe702b3710527442adf6e55a
# 数据已成功合并并保存到 /home/sunyongqian/liuheng/shenchao/Lumos/results_25969/test_combined.csv

# %%
control     = pd.read_csv(train_output_file,   na_values=["", "nan", "NaN", "#NULL#", "#NUL#"])
treatment   = pd.read_csv(test_output_file, na_values=["", "nan", "NaN", "#NULL#", "#NUL#"])
config_file = 'config_yid.json'
with open(config_file) as file:
    config = json.load(file)

# %%
delta_comparer = MetricComparer(config)
metric_delta = delta_comparer.compare(control, treatment)
metric_delta
# Out:
#    Percent Difference  Percent Control  Percent Treatment  P-Value  \
# 0            0.471095       101.802841         102.273936      0.0
#
#    Is Stat-Sig
# 0         True

# %%
bias_tester = BiasTester(config)
bias_results, deviation, is_biased = bias_tester.check_bias(control, treatment)
bias_results
# Out:
#                                               feature  chi_square  \
# 0   isEqualDirectSuperior failed, err=fanweiEmploy...  925.761691
# 1                         the employee does not exist  802.801330
# 6                          [getOtpKey] <:*:> failed:>   17.189147
# 7   [GetWeChatUserInfo] GetWeChatUserInf<:updateFa...   17.189147
# 3      AuthSessionVali<:updateFanweiEmployee failed:>   22.170279
# 4   [securitySessionCheck] GetSecuritySessionFromR...   18.760433
# 5   [securitySessionCheck] CreatAndSaveSessio<:upd...   18.760433
# 2                    not find dictionary type=<:NUM:>   23.703851
# 8                                         no employee   82.952183
# 9                  [SimplePost] failed, <:ERRORPost:>    0.000016
# 11  [updateFanweiEmployee] failed, <:updateEmploye...    0.000704
# 10  [UpdateEmployee] <:SimplePos<:updateFanweiEmpl...    0.000704
#
#           p_value  dof  Percentage Deviation  num bins resample
# 0   7.069314e-198    5             28.942409         6      yes
# 1   5.647329e-144   38             16.974525        39      yes
# 6    2.819868e-02    8              4.924560         9       no
# 7    2.819868e-02    8              4.924560         9       no
# 3    1.426025e-02   10              4.344909        11       no
# 4    8.971872e-03    7              4.002285         8      yes
# 5    8.971872e-03    7              4.002285         8      yes
# 2    3.396598e-02   13              1.905136        14       no
# 8    7.139377e-18    3              1.560080         4      yes
# 9    9.968134e-01    1              0.062536         2       no
# 11   9.788291e-01    1              0.024095         2       no
# 10   9.788291e-01    1              0.024095         2       no

# %%
n_control, n_treatment =bias_tester.normalize_bias(control, treatment, bias_results)
n_bias_results, n_deviation, n_is_biased = bias_tester.check_bias(n_control, n_treatment)
n_bias_results
# Out:
#                                               feature  chi_square  \
# 3      AuthSessionVali<:updateFanweiEmployee failed:>   69.632110
# 4   [securitySessionCheck] GetSecuritySessionFromR...   52.675101
# 5   [securitySessionCheck] CreatAndSaveSessio<:upd...   52.675101
# 6                          [getOtpKey] <:*:> failed:>   53.744151
# 7   [GetWeChatUserInfo] GetWeChatUserInf<:updateFa...   53.744151
# 1                         the employee does not exist  119.266240
# 9                  [SimplePost] failed, <:ERRORPost:>    2.663001
# 11  [updateFanweiEmployee] failed, <:updateEmploye...    2.399652
# 10  [UpdateEmployee] <:SimplePos<:updateFanweiEmpl...    2.399652
# 0   isEqualDirectSuperior failed, err=fanweiEmploy...    3.282433
# 2                    not find dictionary type=<:NUM:>   16.185878
# 8                                         no employee    4.236661
#
#          p_value  dof  Percentage Deviation  num bins resample
# 3   1.753225e-12    7             11.749347         8      yes
# 4   1.364009e-09    6             10.313316         7      yes
# 5   1.364009e-09    6             10.313316         7      yes
# 6   2.642482e-09    7              9.921671         8      yes
# 7   2.642482e-09    7              9.921671         8      yes
# 1   3.995958e-11   35              8.093995        36      yes
# 9   1.027068e-01    1              2.610966         2       no
# 11  1.213623e-01    1              2.480418         2       no
# 10  1.213623e-01    1              2.480418         2       no
# 0   1.937442e-01    2              2.088773         3       no
# 2   1.828701e-01   12              1.827676        13       no
# 8   2.370170e-01    3              1.436031         4       no

# %%
n_metric_delta = delta_comparer.compare(n_control, n_treatment)
n_metric_delta
# Out:
#    Percent Difference  Percent Control  Percent Treatment        P-Value  \
# 0            0.300345       101.969692         102.270038  7.828687e-109
#
#    Is Stat-Sig
# 0         True

# %%
# 保存结果到文件夹
metric_delta.to_csv(os.path.join(results_dir, 'metric_delta.csv'), index=False)
bias_results.to_csv(os.path.join(results_dir, 'bias_results.csv'), index=False)
n_bias_results.to_csv(os.path.join(results_dir, 'n_bias_results.csv'), index=False)
n_metric_delta.to_csv(os.path.join(results_dir, 'n_metric_delta.csv'), index=False)
